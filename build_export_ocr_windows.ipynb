# %%
# delete build files and dist files
import os
import shutil

def delete_build_dist():
    if os.path.exists('build'):
        shutil.rmtree('build')
    if os.path.exists('dist'):
        shutil.rmtree('dist')

delete_build_dist()

# %%
# !pyinstaller ./flask_server.spec
# Out:
# 3890 INFO: PyInstaller: 6.4.0, contrib hooks: 2024.2
# 3890 INFO: Python: 3.10.12 (conda)
# 3905 INFO: Platform: Windows-10-10.0.19045-SP0
# 3936 INFO: Extending PYTHONPATH with paths
# ['d:\\Sample_Captcha_Data']
# 5179 INFO: checking Analysis
# 5179 INFO: Building Analysis because Analysis-00.toc is non existent
# 5179 INFO: Initializing module dependency graph...
# 5245 INFO: Caching module graph hooks...
# 5718 INFO: Analyzing base_library.zip ...
# 9385 INFO: Loading module hook 'hook-heapq.py' from 'C:\\Users\\abhil\\anaconda3\\envs\\tf\\lib\\site-packages\\PyInstaller\\hooks'...
# 9627 INFO: Loading module hook 'hook-encodings.py' from 'C:\\Users\\abhil\\anaconda3\\envs\\tf\\lib\\site-packages\\PyInstaller\\hooks'...
# 14484 INFO: Loading module hook 'hook-pickle.py' from 'C:\\Users\\abhil\\anaconda3\\envs\\tf\\lib\\site-packages\\PyInstaller\\hooks'...
# 18837 INFO: Caching module dependency graph...
# 19119 INFO: Running Analysis Analysis-00.toc
# ...

# %%
# Specify the source and destination paths
exe_name = 'ocr_server.exe'

source_path = './dist/' + exe_name

dest_folder_name = '~/Documents/GitHub/APOS/ocr_server/'
destination_dir = os.path.expanduser(dest_folder_name)

# %%
# check if the destination directory exists, else create it
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

# delete all files in the destination directory
for filename in os.listdir(destination_dir):
    file_path = os.path.join(destination_dir, filename)
    try:
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
    except Exception as e:
        print('Failed to delete %s. Reason: %s' % (file_path, e))

# Copy the file
destination_path = os.path.join(destination_dir, exe_name)
shutil.copyfile(source_path, destination_path)
# Out:
# 'C:\\Users\\abhil/Documents/GitHub/APOS/ocr_server/ocr_server.exe'
